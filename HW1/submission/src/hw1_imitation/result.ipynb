# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import torch.utils.data as data

# %%
### train_loss curve
mse_result_log = pd.read_csv("/scratch/users/alex_zhao/hw1/exp/seed_42_20260210_000228/log.csv")
flow_result_log = pd.read_csv("/scratch/users/alex_zhao/hw1/exp/seed_42_20260211_013904/log.csv")

display(mse_result_log[:2])
display(flow_result_log[:2])
# Out:
#    train_loss  step
# 0    0.988475     0
# 1    0.154109   100
#    train_loss  step
# 0    2.016809     0
# 1    0.853062   100

# %%
sns.lineplot(data=mse_result_log, x="step", y="train_loss", label="MSE")
plt.legend()
plt.show()

# %%
sns.lineplot(data=flow_result_log, x="step", y="train_loss", label="Flow")
plt.legend()
plt.show()

# %%
mse_reward = pd.read_csv("/scratch/users/alex_zhao/hw1/wandb/mse_best/run-k4tyx64p_eval_log.csv")
flow_reward = pd.read_csv("/scratch/users/alex_zhao/hw1/wandb/flow_best/run-lqa8tnkl_eval_log.csv")
display(mse_reward[:2])
display(flow_reward[:2])
# Out:
#    train_step  eval_reward
# 0       10000     0.455195
# 1       20000     0.546915
#    train_step  eval_reward
# 0       10000     0.327366
# 1       20000     0.485967

# %%
sns.lineplot(data=mse_reward, x="train_step", y="eval_reward", label="MSE")
plt.legend()
plt.show()

# %%
sns.lineplot(data=flow_reward, x="train_step", y="eval_reward", label="Flow")
# Out:
# <Axes: xlabel='train_step', ylabel='eval_reward'>
